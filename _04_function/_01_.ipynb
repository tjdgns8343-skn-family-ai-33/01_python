# %%
add = lambda x, y: x+y
print(add(3,5))
# Out:
# 8

# %%
numbers = [1,2,3,4,5]
squared_numbers = map(lambda x: x**2, numbers)
print(list(squared_numbers))
print(squared_numbers)
# Out:
# [1, 4, 9, 16, 25]
# <map object at 0x000001B1F02B2FE0>

# %%
numbers = [1,2,3,4,5,6]
even_numbers = filter(lambda x: x%2 == 0, numbers)
print(list(even_numbers))
# Out:
# [2, 4, 6]

# %%
nums: list[int]


points = [(1,2),(3,1),(5,-1)]
sorted_points = sorted(points, key = lambda x: x[1])
print(sorted_points)
# Out:
# [(5, -1), (3, 1), (1, 2)]

# %%
# 함수의 종류

# param, no return value
def f1(b):
    b = 200
    print(b)
a = 100
f1(a)
print(a)
# Out:
# 200
# 100

# %%
def f2(b):
    b = 'def'
a = 'abc'
f2(a)
print(a)
# Out:
# abc

# %%
# param, return value
def f4(l):
    l[0] = 100

l = [1,2,3]
f4
