# %% [markdown]
# # API
# Application Programming Interface
# (앱 프로그램밍 규격)
# python api를 사용한다 -> python이 제공하는 여러 타입/함수 등을 사용

# %% [markdown]
# # builtins
#
# 파이썬에서 제공하는 기본모듈
# * 내장함수 builtin-functions
# * 내장예외 builtin-exceptions
#
# 별도의 import문 없이 바로 사용가능.
